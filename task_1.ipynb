# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity, mean_squared_error

# %%
image_gray = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# %%
hist = cv2.calcHist([image_gray], [0], None, [256], [0, 256], accumulate=False)
plt.plot(hist)
plt.show()

# %%
def gamma_correction(img, gamma):
    img = img / 255.0
    corrected = np.power(img, gamma)
    return (corrected * 255).astype(np.uint8)

# gamma < 1 и > 1
gamma_light = gamma_correction(image_gray, 0.5)
gamma_dark  = gamma_correction(image_gray, 2.0)

# %%
plt.imshow(gamma_light, cmap='gray')
plt.show()

# %%
plt.imshow(gamma_dark, cmap='gray')
plt.show()

# %%
(ssim, diff) = structural_similarity(image_gray, gamma_light, full=True)
diff = (diff * 255).astype("uint8")
mse = mean_squared_error(image_gray, gamma_light)
print("SSIM: {}".format(ssim))
print("MSE: {}".format(ssim))
# Out:
# SSIM: 0.8865961855237268
# MSE: 0.8865961855237268

# %%
plt.imshow(diff)

# %%
eq_gray = cv2.equalizeHist(image_gray)

E_t = image_gray.mean()
D_t = image_gray.std()
E_s = eq_gray.mean()
D_s = eq_gray.std()

image_corrected = (E_s + (image_gray - E_t) * (D_s / D_t)).clip(0, 255)

# %%
plt.imshow(image_corrected, cmap='gray')
plt.show()

# %%
_, img = cv2.threshold(image_gray, 50, 255, cv2.THRESH_BINARY)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 100, 255, cv2.THRESH_BINARY)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 150, 255, cv2.THRESH_BINARY)
plt.imshow(img, cmap='gray')
plt.show()

# %%
_, img = cv2.threshold(image_gray, 50, 255, cv2.THRESH_BINARY_INV)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 100, 255, cv2.THRESH_BINARY_INV)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 150, 255, cv2.THRESH_BINARY_INV)
plt.imshow(img, cmap='gray')
plt.show()

# %%
_, img = cv2.threshold(image_gray, 50, 255, cv2.THRESH_TRUNC)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 100, 255, cv2.THRESH_TRUNC)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 150, 255, cv2.THRESH_TRUNC)
plt.imshow(img, cmap='gray')
plt.show()

# %%
_, img = cv2.threshold(image_gray, 50, 255, cv2.THRESH_TOZERO)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 100, 255, cv2.THRESH_TOZERO)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 150, 255, cv2.THRESH_TOZERO)
plt.imshow(img, cmap='gray')
plt.show()

# %%
_, img = cv2.threshold(image_gray, 50, 255, cv2.THRESH_TOZERO_INV)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 100, 255, cv2.THRESH_TOZERO_INV)
plt.imshow(img, cmap='gray')
plt.show()

_, img = cv2.threshold(image_gray, 150, 255, cv2.THRESH_TOZERO_INV)
plt.imshow(img, cmap='gray')
plt.show()
